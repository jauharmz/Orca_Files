# %% [markdown]
# <a href="https://colab.research.google.com/github/jauharmz/Orca_Files/blob/antigravity/ORCA_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 00 Importing Libraries

# %%
# @title
# %%capture
# !pip install -q condacolab
import condacolab

# Install a Miniforge version that ships with Python 3.12 to match Colab
condacolab.install_from_url("https://github.com/conda-forge/miniforge/releases/download/24.9.0-0/Miniforge3-24.9.0-0-Linux-x86_64.sh")

# %% [markdown]
# ## RESTART RUNTIME

# %%
# %%capture
import condacolab
condacolab.check()

# Install RDKit into the existing base environment
#!mamba install -c conda-forge rdkit openbabel openbabel-wheel -y
# !mamba install -c conda-forge rdkit openbabel -y
# !npm install localtunnel

# !pip install huggingface_hub py3Dmol streamlit plotly scipy openpyxl streamlit-flow-component
# !git clone https://github.com/jauharmz/Orca_Files.git
# %cd Orca_Files

from huggingface_hub import login, snapshot_download

API_KEY = ''

login(API_KEY)

# %%
import subprocess
import time

# Start Streamlit in Background
print("🚀 Launching Streamlit...")
subprocess.Popen(["streamlit", "run", "streamlit_app/app.py", "--server.address=localhost", "--server.enableCORS=false"])

# Download Cloudflared (Standalone binary, no OpenSSL/Node dependencies)
print("☁️ Downloading Tunnel...")
# !wget -q -O cloudflared https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared

# Start Tunnel
print("🔗 Creating secure link...")
# !nohup ./cloudflared tunnel --url http://localhost:8501 > tunnel.log 2>&1 &

# Display Link
time.sleep(5)
print("\n✅ CLICK THIS LINK TO OPEN APP:")
# !grep -o 'https://.*\.trycloudflare.com' tunnel.log
