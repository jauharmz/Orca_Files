# %% [markdown]
# <a href="https://colab.research.google.com/github/jauharmz/Orca_Files/blob/main/ORCA_COLAB_TEST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install streamlit py3Dmol stmol matplotlib pandas pytest
# !npm install localtunnel

# %%
# !git clone https://github.com/jauharmz/Orca_Files.git
# %cd Orca_Files
# Out:
# fatal: destination path 'Orca_Files' already exists and is not an empty directory.
# /content/Orca_Files

# %%
# !ls
# Out:
# app.py		      p1xs0p_job2.bibtex	 p1xs0vg.ES.hess
# p1xs0.bibtex	      p1xs0p_job2.cpcm		 p1xs0vg.ges
# p1xs0.cpcm	      p1xs0p_job2.cpcm_corr	 p1xs0vg.GS.hess
# p1xs0.cpcm_corr       p1xs0p_job2.densitiesinfo  p1xs0vg.inp
# p1xs0.densitiesinfo   p1xs0p_job2.hess		 p1xs0vg.out
# p1xs0.engrad	      p1xs0p_job2.property.txt	 p1xs0vg.property.txt
# p1xs0.hess	      p1xs0p.out		 p1xs0vg.spectrum
# p1xs0.inp	      p1xs0p.property.txt	 p1xs0.xyz
# p1xs0.opt	      p1xs0.property.txt	 parsers
# p1xs0.out	      p1xs0_trj.xyz		 previews
# p1xs0p.bibtex	      p1xs0vg.bibtex		 README.md
# p1xs0p.cpcm	      p1xs0vg.cis		 requirements.txt
# p1xs0p.cpcm_corr      p1xs0vg.cpcm		 tests
# p1xs0p.densitiesinfo  p1xs0vg.cpcm_corr
# p1xs0p.inp	      p1xs0vg.densitiesinfo

# %%
# Run unit tests
# !python -m pytest tests/test_out_parser.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/Orca_Files
# plugins: langsmith-0.4.45, anyio-4.11.0, typeguard-4.4.4
# collected 7 items
#
# tests/test_out_parser.py::TestDataExtraction::test_parse_job_info FAILED [ 14%]
# tests/test_out_parser.py::TestDataExtraction::test_parse_final_energy PASSED [ 28%]
# tests/test_out_parser.py::TestDataExtraction::test_parse_coordinates PASSED [ 42%]
# tests/test_out_parser.py::TestDataExtraction::test_parse_coordinates_au PASSED [ 57%]
# tests/test_out_parser.py::TestDataExtraction::test_parse_internal_coordinates PASSED [ 71%]
# tests/test_out_parser.py::TestDataExtraction::test_parse_mulliken_overlap_charges PASSED [ 85%]
# tests/test_out_parser.py::TestPerformance::test_parsing_speed PASSED     [100%]
#
# =================================== FAILURES ===================================
# ____________________ TestDataExtraction.test_parse_job_info ____________________
#
# self = <tests.test_out_parser.TestDataExtraction object at 0x796fbe7ce7b0>
#
#     def test_parse_job_info(self):
#         """Test job information parsing."""
#         result = parse_out_file(str(TEST_FILE))
#         assert result.job_info is not None
#         assert result.job_info.basis_set == "pcSseg-3"
#         assert result.job_info.charge == 0
#         assert result.job_info.multiplicity == 1
# >       assert result.job_info.num_electrons == 102
# E       AssertionError: assert 100 == 102
# E        +  where 100 = JobInfo(method='', basis_set='pcSseg-3', charge=0, multiplicity=1, num_electrons=100, job_types=[]).num_electrons
# E        +    where JobInfo(method='', basis_set='pcSseg-3', charge=0, multiplicity=1, num_electrons=100, job_types=[]) = OrcaOutput(job_info=JobInfo(method='', basis_set='pcSseg-3', charge=0, multiplicity=1, num_electrons=100, job_types=[]), final_energy=-662.998374500966, scf_energies=[-663.0808973435953, -662.956341005085, -662.956341005295, -662.9563393082302], optimization_energies=[-663.122932536331, -662.998374500966], coordinates=[('C', 0.976427, 4.012579, -0.06833), ('H', 0.971604, 5.093598, -0.141151), ('C', -0.207403, 3.274284, -0.073561), ('H', -1.155495, 3.793758, -0.152237), ('C', -0.195772, 1.870718, 0.021033), ('H', -1.137315, 1.333318, 0.013423), ('C', 0.99783, 1.158154, 0.123935), ('H', 1.004517, 0.076586, 0.196715), ('C', 2.193282, 1.881474, 0.130898), ('C', 2.162672, 3.293265, 0.034881), ('N', 3.495085, 3.683042, 0.070405), ('H', 3.886918, 4.614616, 0.026043), ('C', 4.233482, 2.53985, 0.181288), ('N', 3.512292, 1.4391, 0.221599), ('N', 5.61245, 2.53443, 0.246025), ('H', 6.050645, 1.626043, 0.330728), ('C', 6.415599, 3.64625, 0.203677), ('O', 6.012079, 4.791913, 0.102554), ('O', 7.701123, 3.286669, 0.289795), ('C', 8.667674, 4.364166, 0.258559), ('H', 8.587641, 4.911654, -0.680346), ('H', 8.507497, 5.035061, 1.102351), ('H', 9.635628, 3.876252, 0.335918)], coordinates_au=[('C', 1....atom_index=5, element='H', isotropic=23.87, anisotropy=5.16), NMRShift(atom_index=7, element='H', isotropic=23.645, anisotropy=5.897), NMRShift(atom_index=11, element='H', isotropic=20.572, anisotropy=11.103), NMRShift(atom_index=15, element='H', isotropic=23.398, anisotropy=6.331), NMRShift(atom_index=20, element='H', isotropic=27.452, anisotropy=8.158), NMRShift(atom_index=21, element='H', isotropic=27.46, anisotropy=8.174), NMRShift(atom_index=22, element='H', isotropic=27.566, anisotropy=7.935), NMRShift(atom_index=0, element='C', isotropic=60.192, anisotropy=163.695), NMRShift(atom_index=2, element='C', isotropic=48.256, anisotropy=183.787), NMRShift(atom_index=4, element='C', isotropic=47.543, anisotropy=183.201), NMRShift(atom_index=6, element='C', isotropic=53.06, anisotropy=165.582), NMRShift(atom_index=8, element='C', isotropic=25.023, anisotropy=156.911), NMRShift(atom_index=9, element='C', isotropic=35.015, anisotropy=146.635), NMRShift(atom_index=12, element='C', isotropic=20.948, anisotropy=93.985), NMRShift(atom_index=16, element='C', isotropic=12.626, anisotropy=-116.346), NMRShift(atom_index=19, element='C', isotropic=120.803, anisotropy=82.153)], j_couplings=[])).job_info
#
# tests/test_out_parser.py:50: AssertionError
# =========================== short test summary info ============================
# FAILED tests/test_out_parser.py::TestDataExtraction::test_parse_job_info - AssertionError: assert 100 == 102
# ========================= 1 failed, 6 passed in 10.49s =========================

# %%
# Run with coverage
# !python -m pytest tests/test_out_parser.py --cov=parsers --cov-report=html
# Out:
# ERROR: usage: __main__.py [options] [file_or_dir] [file_or_dir] [...]
# __main__.py: error: unrecognized arguments: --cov=parsers --cov-report=html
#   inifile: None
#   rootdir: /content/Orca_Files

# %%
# Run specific test
# !python -m pytest tests/test_out_parser.py::test_parse_coordinates -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/Orca_Files
# plugins: langsmith-0.4.45, anyio-4.11.0, typeguard-4.4.4
# collected 0 items
#
# ============================ no tests ran in 0.03s =============================
# ERROR: not found: /content/Orca_Files/tests/test_out_parser.py::test_parse_coordinates
# (no match in any of [<Module test_out_parser.py>])

# %%
# Run performance tests
# !python -m pytest tests/test_out_parser.py -k "performance" -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/Orca_Files
# plugins: langsmith-0.4.45, anyio-4.11.0, typeguard-4.4.4
# collected 7 items / 6 deselected / 1 selected
#
# tests/test_out_parser.py::TestPerformance::test_parsing_speed PASSED     [100%]
#
# ======================= 1 passed, 6 deselected in 2.03s ========================

# %%
# Test parser output
# !python parsers/out_parser.py p1xs0p.out
# Out:
# Method:
# Basis: pcSseg-3
# Charge: 0, Mult: 1
# Final Energy: -662.998375 Eh
# Coordinates: 23 atoms
# Coordinates (a.u.): 23 atoms with atomic numbers and masses
# Internal Coordinates: 23 atoms (Z-matrix)
#   Example: H bonded to atom 1, r=1.0835 Å
# Dipole: 4.734 Debye
# Isotropic Polarizability: 194.75 a.u.
#   Eigenvalues: 107.01, 193.83, 283.40 a.u.
# Orbitals: 11609 occupied, 393 virtual
#   HOMO: -0.000 eV
#   LUMO: -0.814 eV
# Frequencies: 63 modes
#   Range: 44.9 - 3597.4 cm^-1
# Mayer Bond Orders: 66 bonds
# Loewdin Bond Orders: 65 bonds
# Mulliken Overlap Charges: 105 atom pairs
#   Strongest overlap: atoms 6-8, charge=-24.5138
# Mulliken Orbital Populations: 23 atoms
#   0 C: s=3.17, p=2.89, d=0.10, f=0.007
#   1 H: s=0.78, p=0.04
#   2 C: s=3.15, p=2.90, d=0.12, f=0.008
#   ... and 20 more
# Gibbs Free Energy: -662.858808 Eh
# NMR Shifts: 18 nuclei
# J-Couplings: 0 pairs
# Raman Spectrum: 63 modes
#   Strongest: 1592.0 cm^-1 (activity: 895.9)
# Dispersion: DFTD3
#   Energy: -26.38 kcal/mol
# Normal Modes: 1 modes with displacement vectors
#   First mode: 0.0 cm^-1 (0 atoms)
# SCF Iterations: 16 iterations
#   Final: ΔE=-2.10e-10, RMSDP=2.35e-04
# Total Time: 443.7 sec
# Total Run Time: 63 min 0.8 sec (3780.8 sec)
#   Fock Matrix: 395.9 sec (89.2%)
# DFT Grid: 291,858 points
#   6 (Lebedev-590), 12689 pts/atom
# Basis Set: pcSseg-3
#   1305 functions, 0 primitives
#   Elements: C, H, N, O
# Energy Components:
#   Nuclear Repulsion: 839.661550 Eh
#   Electronic Energy: -1502.722221 Eh
#   Kinetic Energy: 660.288591 Eh
#   Potential Energy: -1323.369488 Eh
#   Virial Ratio: 2.00422892
#   XC Energy: -72.670518 Eh (X: -68.601554, C: -4.068964)
# CPCM Solvation:
#   Surface Charge: -0.03192241
#   Corrected Charge: 0.00000000
#   Outlying Charge Correction: 0.00006351 Eh (0.00173 eV)
#   Dielectric Energy: -0.02022446 Eh
# SCF Convergence:
#   Energy Change: -1.43e-09
#   MAX-Density Change: 1.38e-05
#   RMS-Density Change: 4.60e-07
#   DIIS Error: 6.82e-04
#   Orbital Gradient: 4.32e-08
#   Orbital Rotation: 2.00e-07

# %%
# Test JSON export
# !python parsers/out_parser.py p1xs0p.out > output.json

# %%
# Verify section counts
# !python parsers/out_parser.py p1xs0p.out | grep -E "(Coordinates|Bond Orders|Overlap)"
# Out:
# Coordinates: 23 atoms
# Coordinates (a.u.): 23 atoms with atomic numbers and masses
# Internal Coordinates: 23 atoms (Z-matrix)
# Mayer Bond Orders: 66 bonds
# Loewdin Bond Orders: 65 bonds
# Mulliken Overlap Charges: 105 atom pairs

# %%
# !streamlit run app.py &>/content/logs.txt & curl ipv4.icanhazip.com
# !npx localtunnel --port 8501
# Out:
# 34.91.214.107
# ⠙⠹your url is: https://light-eels-fix.loca.lt
